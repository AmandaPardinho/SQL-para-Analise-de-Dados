# %% [markdown]
# # QUERY_1

# %%
SELECT * FROM clientes;

# %% [markdown]
# ![query_1.png](data:image/png;base64,...)

# %% [markdown]
# # QUERY_2

# %%
SELECT id, idade, limite_credito FROM clientes WHERE sexo = 'M' ORDER BY idade DESC;

# %% [markdown]
# ![query_2.png](data:image/png;base64,...)

# %% [markdown]
# # QUERY_3

# %%
SELECT sexo, AVG(idade) AS "media_idade_por_sexo" FROM clientes GROUP BY sexo;

# %% [markdown]
# ![query_3.png](data:image/png;base64,...)
